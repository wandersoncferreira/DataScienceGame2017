# %%
import pandas as pd
import numpy as np
import gzip
import csv
import numpy as np

def build_kaggle_submission(preds, filename="my_submission"):
    """
    Build a compressed Kaggle Submission
    
    preds: array with predictions
    """
    with gzip.open(filename + '.csv.gz', 'wt') as outf:
        fo = csv.writer(outf, lineterminator='\n')
        fo.writerow(["sample_id", "is_listened"])       
        for i, pred in enumerate(preds):
            fo.writerow([i, pred])
            
df =pd.read_csv("preds.csv")

# %%
df = df.rename(columns={"Unnamed: 0": "user_id_id", "0": "prediction"})

# %%
df["prediction"].head()
# Out:
# 0    [[ 0.01311813  0.98688187]]
# 1                    [[ 0.  1.]]
# 2                    [[ 0.  1.]]
# 3                    [[ 0.  1.]]
# 4                  [[ 0.9  0.1]]
# Name: prediction, dtype: object

# %%
np.fromstring('1 2', dtype=int, sep=' ')
np.fromstring('[0.01311813  0.98688187]', dtype=float, sep=' ')
# Out:
# array([], dtype=float64)

# %%
df["prediction"] = df["prediction"].apply(lambda x : np.fromstring(x[2:-2], dtype=float, sep=' ')[-1])

# %%
a = df["prediction"].values

# %%
df["user_id_id"].max()
# Out:
# 17287

# %%
other_sub = pd.read_csv("rand_all_data_m2.csv.gz")

# %%
b = other_sub.ix[17288:]["is_listened"].values

# %%
v = np.hstack((a, b))

# %%
len(v)
# Out:
# 19918

# %%
import gzip
import csv
import numpy as np

def build_kaggle_submission(preds, filename="my_submission"):
    """
    Build a compressed Kaggle Submission
    
    preds: array with predictions
    """
    with gzip.open(filename + '.csv.gz', 'wt') as outf:
        fo = csv.writer(outf, lineterminator='\n')
        fo.writerow(["sample_id", "is_listened"])       
        for i, pred in enumerate(preds):
            fo.writerow([i, pred])

# %%
build_kaggle_submission(v, "invividual")

# %%
a = pd.read_csv("rand_all_data_m2.csv.gz")["is_listened"].values
b = pd.read_csv("rand_test.csv.gz")["is_listened"].values
c = pd.read_csv("note12_4.csv.gz")["is_listened"].values

# %%
d = 0.35 * a + 0.35 * b + 0.3* c

# %%
build_kaggle_submission(d, "merge2")

# %%
a = pd.read_csv("rand_all_data_m2.csv.gz")["is_listened"].values
b = pd.read_csv("rand_test.csv.gz")["is_listened"].values
c = pd.read_csv("note12_4.csv.gz")["is_listened"].values

d = 0.4 * a + 0.4 * b + 0.2* c

build_kaggle_submission(d, "merge3")

# %%
a = pd.read_csv("rand_all_data_m2.csv.gz")["is_listened"].values
b = pd.read_csv("rand_test.csv.gz")["is_listened"].values
c = pd.read_csv("note12_4.csv.gz")["is_listened"].values

d = 0.25 * a + 0.25 * b + 0.5* c

build_kaggle_submission(d, "merge4")

# %%
a = pd.read_csv("rand_all_data_m2.csv.gz")["is_listened"].values
b = pd.read_csv("rand_test.csv.gz")["is_listened"].values
c = pd.read_csv("note12_4.csv.gz")["is_listened"].values

d = 0.35 * a + 0.3 * b + 0.35* c

build_kaggle_submission(d, "merge5")

# %%
a = pd.read_csv("rand_all_data_m2.csv.gz")["is_listened"].values
b = pd.read_csv("rand_test.csv.gz")["is_listened"].values
c = pd.read_csv("note12_4.csv.gz")["is_listened"].values

d = 0.4 * a + 0.3 * b + 0.3* c

build_kaggle_submission(d, "merge6")

# %%
single_model_pred = pd.read_csv("single_model_pred_log.csv")
single_model_auc = pd.read_csv("single_model_auc_log.csv")
rocs = single_model_auc.to_dict()

# %%
### merge7 > 0.74
### merge 8 > 0.78
best = {k:a for k,a in rocs["0"].items() if a > 0.78}
len(best)
# Out:
# 709

# %%
d[0]
# Out:
# 0.95999999999999996

# %%
for k, v in best.items():
    d[k] = d[k]*0.7 + best[k] * 0.3

# %%
build_kaggle_submission(d, "merge8")

# %%
a = pd.read_csv("rand_all_data_m2.csv.gz")["is_listened"].values
b = pd.read_csv("rand_test.csv.gz")["is_listened"].values
c = pd.read_csv("note12_4.csv.gz")["is_listened"].values

d = 0.4 * a + 0.3 * b + 0.3* c

single_model_pred = pd.read_csv("single_model_pred_rand.csv")
single_model_auc = pd.read_csv("single_model_auc_rand.csv")
rocs = single_model_auc.to_dict()

best = {k:a for k,a in rocs["0"].items() if a > 0.74}
print(len(best))

for k, v in best.items():
    d[k] = d[k]*0.6 + best[k] * 0.4
    
build_kaggle_submission(d, "merge9")
# Out:
# 1967

# %%
a = pd.read_csv("rand_all_data_m2.csv.gz")["is_listened"].values
b = pd.read_csv("rand_test.csv.gz")["is_listened"].values
c = pd.read_csv("note12_4.csv.gz")["is_listened"].values

d = 0.4 * a + 0.3 * b + 0.3* c

single_model_pred = pd.read_csv("single_model_pred_rand.csv")
single_model_auc = pd.read_csv("single_model_auc_rand.csv")
rocs = single_model_auc.to_dict()

best = {k:a for k,a in rocs["0"].items() if a > 0.84}
print(len(best))

for k, v in best.items():
    d[k] = d[k]*0.8 + best[k] * 0.2
    
build_kaggle_submission(d, "merge10")
# Out:
# 521

# %% [markdown]
# ### Melhorando users com poucos registros

# %%
a = pd.read_csv("rand_all_data_m2.csv.gz")["is_listened"].values
b = pd.read_csv("rand_test.csv.gz")["is_listened"].values
c = pd.read_csv("note12_4.csv.gz")["is_listened"].values

d = 0.4 * a + 0.3 * b + 0.3* c

threshold = 15
register_count = pd.read_csv("register_count.csv")
users_few_registers = register_count[(register_count["user_id"] <= threshold)].index

best = {k:a for k,a in rocs["0"].items() if a > 0.84}
print(len(users_few_registers))

for k in users_few_registers:
    d[k] = d[k]*0.5 + 0.54207543056463925 * 0.5
    
build_kaggle_submission(d, "merge11")
# Out:
# 1489

# %%
a = pd.read_csv("rand_all_data_m2.csv.gz")["is_listened"].values
b = pd.read_csv("rand_2_models_threshold_1.csv.gz")["is_listened"].values
#b = pd.read_csv("rand_test.csv.gz")["is_listened"].values
c = pd.read_csv("note12_4.csv.gz")["is_listened"].values

d = 0.4 * a + 0.3 * b + 0.3* c

build_kaggle_submission(d, "merge16")

# %%
a = pd.read_csv("rand_all_data_m2.csv.gz")["is_listened"].values
b = pd.read_csv("rand_2_models_threshold_1.csv.gz")["is_listened"].values
#b = pd.read_csv("rand_test.csv.gz")["is_listened"].values 
c = pd.read_csv("note12_4.csv.gz")["is_listened"].values
d = pd.read_csv("rand_2_models_threshold_5.csv.gz")["is_listened"].values

e = 0.25 * a + 0.3 * b + 0.25* c + 0.2*d

build_kaggle_submission(e, "merge17")

# %%
a = pd.read_csv("rand_all_data_m2.csv.gz")["is_listened"].values
b = pd.read_csv("rand_2_models_threshold_1.csv.gz")["is_listened"].values
#b = pd.read_csv("rand_test.csv.gz")["is_listened"].values 
c = pd.read_csv("note12_4.csv.gz")["is_listened"].values
d = pd.read_csv("rand_2_models_threshold_5.csv.gz")["is_listened"].values

e = 0.25 * a + 0.3 * b + 0.25* c + 0.2*d


new_model_pred = pd.read_csv("only_flow_above_30regs.csv").drop("Unnamed: 0", axis=1)
new_preds = new_model_pred.to_dict()
users = new_model_pred["user_id_id"].unique()

for user in users:
    #e[int(user)] = (e[int(user)] * 0.5) + (new_model_pred[new_model_pred["user_id_id"] == user]["prediction"].values[0]*0.5)
    e[int(user)] = (e[int(user)] * 0.5) + (new_model_pred[new_model_pred["user_id_id"] == user]["prediction"].values[0]*0.5)
build_kaggle_submission(e, "merge18")

# %%
a = pd.read_csv("rand_all_data_m2.csv.gz")["is_listened"].values
b = pd.read_csv("rand_2_models_threshold_1.csv.gz")["is_listened"].values
#b = pd.read_csv("rand_test.csv.gz")["is_listened"].values 
c = pd.read_csv("note12_4.csv.gz")["is_listened"].values
d = pd.read_csv("rand_2_models_threshold_5.csv.gz")["is_listened"].values
f = pd.read_csv("note18_2.csv.gz")["is_listened"].values

e = 0.2 * a + 0.2 * b + 0.2* c + 0.2*d *0.2*f


# new_model_pred = pd.read_csv("only_flow_above_30regs.csv").drop("Unnamed: 0", axis=1)
# new_preds = new_model_pred.to_dict()
# users = new_model_pred["user_id_id"].unique()

# for user in users:
#     #e[int(user)] = (e[int(user)] * 0.5) + (new_model_pred[new_model_pred["user_id_id"] == user]["prediction"].values[0]*0.5)
#     e[int(user)] = (e[int(user)] * 0.5) + (new_model_pred[new_model_pred["user_id_id"] == user]["prediction"].values[0]*0.5)
build_kaggle_submission(e, "merge19")

# %%
a = pd.read_csv("rand_all_data_m2.csv.gz")["is_listened"].values
b = pd.read_csv("rand_2_models_threshold_1.csv.gz")["is_listened"].values
#b = pd.read_csv("rand_test.csv.gz")["is_listened"].values 
c = pd.read_csv("note12_4.csv.gz")["is_listened"].values
d = pd.read_csv("rand_2_models_threshold_5.csv.gz")["is_listened"].values
f = pd.read_csv("note18_2.csv.gz")["is_listened"].values

e = 0.25 * a + 0.25 * b + 0.2* c + 0.2*d *0.1*f


# new_model_pred = pd.read_csv("only_flow_above_30regs.csv").drop("Unnamed: 0", axis=1)
# new_preds = new_model_pred.to_dict()
# users = new_model_pred["user_id_id"].unique()

# for user in users:
#     #e[int(user)] = (e[int(user)] * 0.5) + (new_model_pred[new_model_pred["user_id_id"] == user]["prediction"].values[0]*0.5)
#     e[int(user)] = (e[int(user)] * 0.5) + (new_model_pred[new_model_pred["user_id_id"] == user]["prediction"].values[0]*0.5)
build_kaggle_submission(e, "merge20")

# %%
a = pd.read_csv("rand_all_data_m2.csv.gz")["is_listened"].values
b = pd.read_csv("rand_2_models_threshold_1.csv.gz")["is_listened"].values
#b = pd.read_csv("rand_test.csv.gz")["is_listened"].values 
c = pd.read_csv("note12_4.csv.gz")["is_listened"].values
d = pd.read_csv("rand_2_models_threshold_5.csv.gz")["is_listened"].values
f = pd.read_csv("note18_2.csv.gz")["is_listened"].values


#e = 0.25 * a + 0.3 * b + 0.25* c + 0.2*d
e = 0.2 * a + 0.25 * b + 0.2* c + 0.2*d *0.15*f


# new_model_pred = pd.read_csv("only_flow_above_30regs.csv").drop("Unnamed: 0", axis=1)
# new_preds = new_model_pred.to_dict()
# users = new_model_pred["user_id_id"].unique()

# for user in users:
#     #e[int(user)] = (e[int(user)] * 0.5) + (new_model_pred[new_model_pred["user_id_id"] == user]["prediction"].values[0]*0.5)
#     e[int(user)] = (e[int(user)] * 0.5) + (new_model_pred[new_model_pred["user_id_id"] == user]["prediction"].values[0]*0.5)
build_kaggle_submission(e, "merge21")

# %% [markdown]
# ### Verify Correlation

# %%
submissions_to_consider = ["note18_2.csv.gz",
                           "rand_all_data_m2.csv.gz",
                           "rand_2_models_threshold_1.csv.gz",
                           "rand_2_models_threshold_5.csv.gz",
                           "rand_2_models_threshold_30.csv.gz",
                           "note12_4.csv.gz",
                           "note12_3.csv.gz",
                           "note12_1.csv.gz",
                          "xgb_all_data_m2.csv.gz",
                          "rand_2m_data4_2.csv.gz",
                          "note19_1.csv.gz",
                          "note20_1.csv.gz",
                          "note21_1.csv.gz",
                          "note21_2.csv.gz"]

corr_df = pd.DataFrame()

for submission in submissions_to_consider:
    df = pd.read_csv(submission)
    corr_df[submission.split(".")[0]] = df["is_listened"]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(corr_df.corr(), annot=True)
plt.show()

# %%
corr_df.corr()
# Out:
#                             note18_2  rand_all_data_m2  \
# note18_2                    1.000000          0.658492
# rand_all_data_m2            0.658492          1.000000
# rand_2_models_threshold_1   0.653898          0.752202
# rand_2_models_threshold_5   0.630431          0.736299
# rand_2_models_threshold_30  0.651401          0.709166
# note12_4                    0.712131          0.693533
# note12_3                    0.741057          0.721719
# note12_1                    0.622408          0.742443
# xgb_all_data_m2             0.784445          0.752243
# rand_2m_data4_2             0.645233          0.757856
# note19_1                    0.767377          0.640064
#
#                             rand_2_models_threshold_1  \
# note18_2                                     0.653898
# rand_all_data_m2                             0.752202
# rand_2_models_threshold_1                    1.000000
# rand_2_models_threshold_5                    0.750017
# rand_2_models_threshold_30                   0.716000
# note12_4                                     0.691530
# note12_3                                     0.726106
# note12_1                                     0.738695
# xgb_all_data_m2                              0.754850
# rand_2m_data4_2                              0.752497
# note19_1                                     0.656625
#
#                             rand_2_models_threshold_5  \
# note18_2                                     0.630431
# rand_all_data_m2                             0.736299
# rand_2_models_threshold_1                    0.750017
# rand_2_models_threshold_5                    1.000000
# rand_2_models_threshold_30                   0.712677
# note12_4                                     0.642985
# note12_3                                     0.683142
# note12_1                                     0.720874
# xgb_all_data_m2                              0.726190
# rand_2m_data4_2                              0.735622
# note19_1                                     0.628150
#
#                             rand_2_models_threshold_30  note12_4  note12_3  \
# note18_2                                      0.651401  0.712131  0.741057
# rand_all_data_m2                              0.709166  0.693533  0.721719
# rand_2_models_threshold_1                     0.716000  0.691530  0.726106
# rand_2_models_threshold_5                     0.712677  0.642985  0.683142
# rand_2_models_threshold_30                    1.000000  0.608592  0.638821
# note12_4                                      0.608592  1.000000  0.817699
# note12_3                                      0.638821  0.817699  1.000000
# note12_1                                      0.693789  0.673978  0.698089
# xgb_all_data_m2                               0.699780  0.750483  0.791821
# rand_2m_data4_2                               0.704239  0.683272  0.712405
# note19_1                                      0.579487  0.773954  0.818012
#
#                             note12_1  xgb_all_data_m2  rand_2m_data4_2  \
# note18_2                    0.622408         0.784445         0.645233
# rand_all_data_m2            0.742443         0.752243         0.757856
# rand_2_models_threshold_1   0.738695         0.754850         0.752497
# rand_2_models_threshold_5   0.720874         0.726190         0.735622
# rand_2_models_threshold_30  0.693789         0.699780         0.704239
# note12_4                    0.673978         0.750483         0.683272
# note12_3                    0.698089         0.791821         0.712405
# note12_1                    1.000000         0.708483         0.742682
# xgb_all_data_m2             0.708483         1.000000         0.746416
# rand_2m_data4_2             0.742682         0.746416         1.000000
# note19_1                    0.616245         0.777574         0.624082
#
#                             note19_1
# note18_2                    0.767377
# rand_all_data_m2            0.640064
# rand_2_models_threshold_1   0.656625
# rand_2_models_threshold_5   0.628150
# rand_2_models_threshold_30  0.579487
# note12_4                    0.773954
# note12_3                    0.818012
# note12_1                    0.616245
# xgb_all_data_m2             0.777574
# rand_2m_data4_2             0.624082
# note19_1                    1.000000

# %%
submissions_to_consider = ["note18_2.csv.gz",
                           "rand_all_data_m2.csv.gz",
                           "rand_2_models_threshold_1.csv.gz",
                           "rand_2_models_threshold_5.csv.gz",
                           "note12_4.csv.gz"]

submissions_to_consider = ["merge" + str(i) + ".csv.gz" for i in range(2, 26)]
corr_df = pd.DataFrame()

for submission in submissions_to_consider:
    df = pd.read_csv(submission)
    corr_df[submission.split(".")[0]] = df["is_listened"]
    
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 10))
sns.heatmap(corr_df.corr(), annot=True)
plt.show()

# %%
a = pd.read_csv("merge17.csv.gz")["is_listened"].values
b = pd.read_csv("merge18.csv.gz")["is_listened"].values

c = 0.7*a + 0.3*b

# new_model_pred = pd.read_csv("only_flow_above_30regs.csv").drop("Unnamed: 0", axis=1)
# new_preds = new_model_pred.to_dict()
# users = new_model_pred["user_id_id"].unique()

# for user in users:
#     #e[int(user)] = (e[int(user)] * 0.5) + (new_model_pred[new_model_pred["user_id_id"] == user]["prediction"].values[0]*0.5)
#     e[int(user)] = (e[int(user)] * 0.5) + (new_model_pred[new_model_pred["user_id_id"] == user]["prediction"].values[0]*0.5)
build_kaggle_submission(c, "merge22")

# %%
a = pd.read_csv("rand_all_data_m2.csv.gz")["is_listened"].values
b = pd.read_csv("rand_2_models_threshold_1.csv.gz")["is_listened"].values
#b = pd.read_csv("rand_test.csv.gz")["is_listened"].values 
c = pd.read_csv("note12_4.csv.gz")["is_listened"].values
c2 = pd.read_csv("note12_3.csv.gz")["is_listened"].values
d = pd.read_csv("rand_2_models_threshold_30.csv.gz")["is_listened"].values

e = 0.25 * a + 0.3 * b + 0.2* c + 0.05*c2 + 0.2*d

build_kaggle_submission(e, "merge23")

# %% [markdown]
# 17 e 23

# %%
ts = pd.read_csv("group1_ts_xgboost.csv")

test = pd.read_csv("../data/test_data4.csv")[["sample_id", "user_id"]]
test["user_id_id"] = test["user_id"]

# %%
test = pd.merge(test, ts, on="user_id_id")

# %%
test[["sample_id", "prediction"]]
# Out:
#        sample_id  prediction
# 0              1    0.377108
# 1              2    0.255805
# 2              3    0.820735
# 3              4    0.756247
# 4              5    0.107689
# 5              7    0.591420
# 6              8    0.597185
# 7              9    0.973862
# 8             10    0.327765
# 9             11    0.959089
# 10            12    0.867112
# 11            13    0.939457
# 12            15    0.989015
# 13            17    0.179048
# 14            18    0.682910
# 15            20    0.713767
# 16            21    0.648291
# 17            22    0.919649
# 18            23    0.847090
# 19            24    0.472492
# 20            25    0.148844
# 21            26    0.461952
# 22            27    0.453139
# 23            28    0.990285
# 24            30    0.340899
# 25            31    0.935055
# 26            32    0.967564
# 27            33    0.721215
# 28            34    0.960436
# 29            35    0.501359
# ...          ...         ...
# 17258      19884    0.169597
# 17259      19885    0.760335
# 17260      19886    0.720541
# 17261      19888    0.711947
# 17262      19889    0.238351
# 17263      19890    0.931690
# 17264      19892    0.654745
# 17265      19893    0.213682
# 17266      19894    0.939981
# 17267      19895    0.878740
# 17268      19897    0.035041
# 17269      19898    0.288893
# 17270      19899    0.651617
# 17271      19900    0.766239
# 17272      19901    0.525199
# 17273      19902    0.313059
# 17274      19903    0.090405
# 17275      19904    0.329471
# 17276      19905    0.081699
# 17277      19906    0.594349
# 17278      19908    0.786704
# 17279      19909    0.698295
# 17280      19910    0.450244
# 17281      19911    0.098149
# 17282      19912    0.933140
# 17283      19913    0.079529
# 17284      19914    0.804707
# 17285      19915    0.939896
# 17286      19916    0.723055
# 17287      19917    0.910767
#
# [17288 rows x 2 columns]

# %%
ts
# Out:
#        Unnamed: 0  prediction  user_id_id
# 0               0    0.981403         0.0
# 1               1    0.928719         1.0
# 2               2    0.854829         2.0
# 3               3    0.978622         3.0
# 4               4    0.388160         4.0
# 5               5    0.923790         5.0
# 6               6    0.978626         6.0
# 7               7    0.047910         7.0
# 8               8    0.918640         8.0
# 9               9    0.635383         9.0
# 10             10    0.770613        10.0
# 11             11    0.358905        11.0
# 12             12    0.917235        12.0
# 13             13    0.985290        13.0
# 14             14    0.976026        14.0
# 15             15    0.977972        15.0
# 16             16    0.347267        16.0
# 17             17    0.640680        17.0
# 18             18    0.484806        18.0
# 19             19    0.795401        19.0
# 20             20    0.842775        20.0
# 21             21    0.989962        21.0
# 22             22    0.509437        22.0
# 23             23    0.981427        23.0
# 24             24    0.955218        24.0
# 25             25    0.556387        25.0
# 26             26    0.943979        26.0
# 27             27    0.929964        27.0
# 28             28    0.912200        28.0
# 29             29    0.965896        29.0
# ...           ...         ...         ...
# 17258       17258    0.087163     17206.0
# 17259       17259    0.450477     17215.0
# 17260       17260    0.095651     17214.0
# 17261       17261    0.739963     17213.0
# 17262       17262    0.177352     17212.0
# 17263       17263    0.138645     17211.0
# 17264       17264    0.285813     17210.0
# 17265       17265    0.135295     17209.0
# 17266       17266    0.814877     17208.0
# 17267       17267    0.040554     17236.0
# 17268       17268    0.132875     17231.0
# 17269       17269    0.105383     17226.0
# 17270       17270    0.833933     17217.0
# 17271       17271    0.139236     17244.0
# 17272       17272    0.248664     17245.0
# 17273       17273    0.510208     17247.0
# 17274       17274    0.819326     17218.0
# 17275       17275    0.414080     17232.0
# 17276       17276    0.088915     17233.0
# 17277       17277    0.117979     17234.0
# 17278       17278    0.987230     17235.0
# 17279       17279    0.126768     17243.0
# 17280       17280    0.933555     17242.0
# 17281       17281    0.640058     17241.0
# 17282       17282    0.292750     17240.0
# 17283       17283    0.042491     17223.0
# 17284       17284    0.767585     17222.0
# 17285       17285    0.113148     17221.0
# 17286       17286    0.678348     17220.0
# 17287       17287    0.939223     17219.0
#
# [17288 rows x 3 columns]

# %%
a = pd.read_csv("rand_all_data_m2.csv.gz")["is_listened"].values
b = pd.read_csv("rand_2_models_threshold_1.csv.gz")["is_listened"].values
#b2 = pd.read_csv("note21_1.csv.gz")["is_listened"].values 
c = pd.read_csv("note12_4.csv.gz")["is_listened"].values
c2 = pd.read_csv("note12_3.csv.gz")["is_listened"].values
d = pd.read_csv("rand_2_models_threshold_30.csv.gz")["is_listened"].values


e = 0.25 * a + 0.3 * b + 0.2* c + 0.05*c2 + 0.2*d

ts = pd.read_csv("group1_ts_xgboost.csv")

ts = test
for i in ts["sample_id"].values:
    #print(ts.iloc[i]["sample_id"])
    #print(ts[ts["sample_id"] == i]["prediction"].values * 0.3)
    e[int(ts.iloc[i]["sample_id"])] = e[int(ts.iloc[i]["sample_id"])]*0.7 + ts[ts["sample_id"] == i]["prediction"].values * 0.3
    
build_kaggle_submission(e, "merge24")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6c93cc718432> in <module>()
#      11 ts = pd.read_csv("group1_ts_xgboost.csv")
#      12
# ---> 13 ts = test
#      14 for i in ts["sample_id"].values:
#      15     #print(ts.iloc[i]["sample_id"])
#
# NameError: name 'test' is not defined

# %%
a = pd.read_csv("rand_all_data_m2.csv.gz")["is_listened"].values
b = pd.read_csv("rand_2_models_threshold_1.csv.gz")["is_listened"].values
b2 = pd.read_csv("note21_2.csv.gz")["is_listened"].values 
c = pd.read_csv("note12_4.csv.gz")["is_listened"].values
c2 = pd.read_csv("note12_3.csv.gz")["is_listened"].values
d = pd.read_csv("rand_2_models_threshold_30.csv.gz")["is_listened"].values


e = 0.2 * a + 0.25 * b + 0.15* c + 0.05*c2 + 0.2*d + 0.15*b2

# ts = pd.read_csv("group1_ts_xgboost.csv")

# ts = test
# for i in ts["sample_id"].values:
#     #print(ts.iloc[i]["sample_id"])
#     #print(ts[ts["sample_id"] == i]["prediction"].values * 0.3)
#     e[int(ts.iloc[i]["sample_id"])] = e[int(ts.iloc[i]["sample_id"])]*0.7 + ts[ts["sample_id"] == i]["prediction"].values * 0.3
    
build_kaggle_submission(e, "merge25")

# %%
a = pd.read_csv("rand_all_data_m2.csv.gz")["is_listened"].values
b = pd.read_csv("rand_2_models_threshold_1.csv.gz")["is_listened"].values
b2 = pd.read_csv("note21_2.csv.gz")["is_listened"].values 
c = pd.read_csv("note12_4.csv.gz")["is_listened"].values
c2 = pd.read_csv("note12_3.csv.gz")["is_listened"].values
d = pd.read_csv("rand_2_models_threshold_30.csv.gz")["is_listened"].values


e = 0.25 * a + 0.3 * b + 0.2* c + 0.05*c2 + 0.08*d + 0.07*b2

# ts = pd.read_csv("group1_ts_xgboost.csv")

# ts = test
# for i in ts["sample_id"].values:
#     #print(ts.iloc[i]["sample_id"])
#     #print(ts[ts["sample_id"] == i]["prediction"].values * 0.3)
#     e[int(ts.iloc[i]["sample_id"])] = e[int(ts.iloc[i]["sample_id"])]*0.7 + ts[ts["sample_id"] == i]["prediction"].values * 0.3
    
build_kaggle_submission(e, "merge26")

# %%
submissions_to_consider = ["note18_2.csv.gz",
                           "rand_all_data_m2.csv.gz",
                           "rand_2_models_threshold_1.csv.gz",
                           "rand_2_models_threshold_5.csv.gz",
                           "note12_4.csv.gz"]

submissions_to_consider = ["merge" + str(i) + ".csv.gz" for i in range(2, 26)]
corr_df = pd.DataFrame()

for submission in submissions_to_consider:
    df = pd.read_csv(submission)
    corr_df[submission.split(".")[0]] = df["is_listened"]
    
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 10))
sns.heatmap(corr_df.corr(), annot=True)
plt.show()

# %%
a = pd.read_csv("merge23.csv.gz")["is_listened"].values
b = pd.read_csv("merge15.csv.gz")["is_listened"].values
b2 = pd.read_csv("merge14.csv.gz")["is_listened"].values 
c = pd.read_csv("merge13.csv.gz")["is_listened"].values
c2 = pd.read_csv("merge12.csv.gz")["is_listened"].values
d = pd.read_csv("merge11.csv.gz")["is_listened"].values


e = 0.25 * a + 0.25 * b + 0.2 * b2 + 0.15* c + 0.1*c2 + 0.15*d 

# ts = pd.read_csv("group1_ts_xgboost.csv")

# ts = test
# for i in ts["sample_id"].values:
#     #print(ts.iloc[i]["sample_id"])
#     #print(ts[ts["sample_id"] == i]["prediction"].values * 0.3)
#     e[int(ts.iloc[i]["sample_id"])] = e[int(ts.iloc[i]["sample_id"])]*0.7 + ts[ts["sample_id"] == i]["prediction"].values * 0.3
    
build_kaggle_submission(e, "merge_supremo")
